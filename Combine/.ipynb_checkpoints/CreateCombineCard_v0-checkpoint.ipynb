# %%
card_name = 'q2only_test'

# %% [markdown]
# # Import

# %%
import sys, os
from glob import glob
sys.path.append('../lib')

# %%
import numpy as np
import uproot as ur
import ROOT as rt
rt.gErrorIgnoreLevel = rt.kError
rt.RooMsgService.instance().setGlobalKillBelow(rt.RooFit.ERROR)
import root_numpy as rtnp

from analysis_utilities import drawOnCMSCanvas, extarct, extarct_multiple, createSel
from histo_utilities import create_TH1D, create_TH2D, std_color_list
from cebefo_style import Set_2D_colz_graphics

import CMS_lumi, tdrstyle
tdrstyle.setTDRStyle()
CMS_lumi.writeExtraText = 1
CMS_lumi.extraText = "     Preliminary"

donotdelete = []
# Out:
# Welcome to JupyROOT 6.12/07

# %% [markdown]
# # Create histograms file

# %%
file_loc = {
# 'data' : '../data/cmsRD/Run2018D/B02DstMu_190517_BPH*.root',
'mu'   : '../data/cmsMC_private/BPH_Tag-B0_MuNuDmst-pD0bar-kp_13TeV-pythia8_SoftQCD_PTFilter5_0p0-evtgen_HQET2_central_PU35_10-2-3_v0/B02DstMu_candidates/out*.root',
'tau'  : '../data/cmsMC_private/BPH_Tag-B0_TauNuDmst-pD0bar-kp-t2mnn_pythia8_SoftQCD_PTFilter5_0p0-evtgen_HQET2_central_PU35_10-2-3_v0/B02DstMu_candidates/out*.root'
}

branches = ['q2', 'Est_mu', 'M2_miss',
            'mass_MuDst', 'cos_MuDst_vtxBest'
           ]

dSet = {}
for k, fn in file_loc.iteritems():
    dSet[k] = extarct_multiple(fn, branches=branches, flag=k)
    print k, ':', dSet[k]['Est_mu'].shape[0], 'candidates'
# Out:
# mu : 15963 candidates
# tau : 7222 candidates

# %%
analysis_selection = {
'mass_MuDst'      : ['<', 5.280],
'cos_MuDst_vtxBest' : ['>', 0.98]
}

binning = {
'q2'      : [10, -2, 10.7]
# 'q2'      : [4, -2, 10.7]
# 'M2_miss' : [40/2, -5, 10]
# 'Est_mu'  : [30/2, 0.10, 2.500]
}

# %%
histo= {}
for k in file_loc.keys():
#     histo[k] = rt.TH3F('h_'+k, k, 
#                      binning['q2'][0], binning['q2'][1], binning['q2'][2],
#                      binning['M2_miss'][0], binning['M2_miss'][1], binning['M2_miss'][2],      
#                      binning['Est_mu'][0], binning['Est_mu'][1], binning['Est_mu'][2]
#                     )
    histo[k] = rt.TH1F(k, k, 
                     binning['q2'][0], binning['q2'][1], binning['q2'][2]
                    )

    d = dSet[k]
    sel = createSel(d, analysis_selection)
#     rtnp.fill_hist(histo[k], np.column_stack((d['q2'][sel], d['M2_miss'][sel], d['Est_mu'][sel])))
    rtnp.fill_hist(histo[k], d['q2'][sel])
    
# Add overflow in the last visible bin

# %%
rawR_inj = 0.2
N_B2mu_inj = 1000

sel = createSel(dSet['mu'], analysis_selection)
n_mu = np.random.poisson(lam=N_B2mu_inj)
idx = np.random.randint(0, np.sum(sel), size=(n_mu, ))
d_mu = dSet['mu']['q2'][sel]
d_mu = d_mu[idx]

sel = createSel(dSet['tau'], analysis_selection)
n_tau = np.random.poisson(lam=N_B2mu_inj*rawR_inj)
idx = np.random.randint(0, np.sum(sel), size=(n_tau, ))
d_tau = dSet['tau']['q2'][sel]
d_tau = d_tau[idx]

histo['data'] = rt.TH1F('dataObs', 'data obs', 
                        binning['q2'][0], binning['q2'][1], binning['q2'][2]
                       )
rtnp.fill_hist(histo['data'], np.concatenate((d_mu, d_tau)))
print n_mu, n_tau
print 'r_toy = {:.2f}%'.format(100.*n_tau/n_mu)
# Out:
# 981 200
# r_toy = 20.39%

# %% [markdown]
# Scale according expectation and save file

# %%
histo['mu'].Scale(1./histo['mu'].Integral())
histo['tau'].Scale(1./histo['tau'].Integral())

# %%
histo_file_loc = '../data/_root/histos4combine_{}.root'.format(card_name)
tf = rt.TFile(histo_file_loc, 'recreate')
for k,v in histo.iteritems():
    v.Write()
tf.Close()

# %%
leg = rt.TLegend(0.2, 0.7, 0.4, 0.9)
leg.SetLineWidth(0)
leg.SetBorderSize(0)

histo['data'].Sumw2()
histo['data'].SetMarkerColor(1)
histo['data'].SetMarkerStyle(20)
histo['data'].SetLineColor(1)
histo['data'].SetXTitle('q^{2} [GeV^{2}]')
histo['data'].SetYTitle('Events')
leg.AddEntry(histo['data'], 'Pseudo-data', 'lep')

histo['mu'].Scale(N_B2mu_inj/histo['mu'].Integral())
histo['mu'].SetLineColor(4)
leg.AddEntry(histo['mu'], 'Mu', 'lep')

histo['tau'].Scale(N_B2mu_inj*rawR_inj/histo['tau'].Integral())
histo['tau'].SetLineColor(2)
leg.AddEntry(histo['tau'], 'Tau', 'lep')

h_sum = histo['mu'].Clone('h_sum')
h_sum.Add(histo['tau'])
h_sum.SetLineColor(16)
leg.AddEntry(h_sum, 'Pred', 'lep')

CMS_lumi.extraText = "     Simulation Preliminary"
c = drawOnCMSCanvas(CMS_lumi, [histo['data'], h_sum, histo['mu'], histo['tau']], 'same')
leg.Draw()
c.Draw()

# %% [markdown]
# # Write the card

# %%
sig_processes = ['tau', 'mu']

# %%
card_location = 'cards/{}.txt'.format(card_name)
fc = open(card_location, 'w')

# %%
# number of different categories
card = 'imax 1\n'
# number of processes minus one
card += 'jmax {}\n'.format(len(sig_processes)-1)
# number of nuissance parameters
card += 'kmax *\n'
card += '-------------------------------\n'

# %%
card += 'shapes * cat1 ' + histo_file_loc + ' $PROCESS $PROCESS__$SYSTEMATIC\n'
card += '-------------------------------\n'

# %%
card += 'bin cat1\n'
card += 'observation {:.0f}\n'.format(histo['data'].Integral())
card += '-------------------------------\n'

# %%
card += 'bin ' + ' '.join(['cat1']*2) + '\n'
card += 'process ' + ' '.join(sig_processes) + '\n'

# Zero or negative for sig and positive for bkg
card += 'process ' + '0 1\n'

# Expected rate
rate_str = ' 1'*len(sig_processes) #Both tau and mu are set to 1 because rate is floated below
card += 'rate ' + rate_str + '\n'
card += '-------------------------------\n'

# %% [markdown]
# Add additional rate parameters

# %%
card += 'N_B2mu rateParam cat1 tau {}\n'.format(N_B2mu_inj, N_B2mu_inj/10., N_B2mu_inj*10.)
card += 'N_B2mu rateParam cat1 mu {}\n'.format(N_B2mu_inj)
card += '-------------------------------\n'

# %%
print card
# Out:
# imax 1
# jmax 1
# kmax *
# -------------------------------
# shapes * cat1 ../data/_root/histos4combine_q2only_test.root $PROCESS $PROCESS__$SYSTEMATIC
# -------------------------------
# bin cat1
# observation 1167
# -------------------------------
# bin cat1 cat1
# process tau mu
# process 0 1
# rate  1 1
# -------------------------------
# N_B2mu rateParam cat1 tau 1000
# N_B2mu rateParam cat1 mu 1000
# -------------------------------

# %%
fc.write(card)
fc.close()

# %% [markdown]
# ### Create output directory

# %%
outdir = 'results/' + card_name

if os.path.isdir(outdir):
    os.system('rm -rf ' + outdir)
os.system('mkdir ' + outdir);

# %% [markdown]
# # Run Combine

# %% [markdown]
# ### Run the Maximum Likelyhood fit

# %%
cmd = 'combine'
cmd += ' -M FitDiagnostics'
cmd += ' --robustFit 1'
cmd += ' --skipBOnlyFit'
cmd += ' -d ' + card_location
cmd += ' -D ' + histo['data'].GetName()
cmd += ' --setParameters r=0.1'
cmd += ' --setParameterRanges r=0.001,1'
cmd += ' --trackParameters N_B2mu'
cmd += ' -n {}'.format(card_name)
cmd += ' --out ' + outdir
cmd += ' --saveShapes --saveWithUncertainties'
cmd += ' --plots'
cmd += ' --verbose 9'

# %%
print cmd
os.system(cmd)
os.system('mv combine_logger.out ' + outdir + '/')
os.system('mv ./*.root ' + outdir + '/')
# Out:
# combine -M FitDiagnostics --robustFit 1 --skipBOnlyFit -d cards/q2only_test.txt -D dataObs --setParameters r=0.1 --setParameterRanges r=0.001,1 --trackParameters N_B2mu -n q2only_test --out results/q2only_test --saveShapes --saveWithUncertainties --plots --verbose 9
# 0
#    Options for Robust Minimizer ::
#         Tolerance  0.1
#         Strategy   0
#         Type,Algo  Minuit2,Migrad
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# import (../data/_root/histos4combine_q2only_test.root,dataObs) -> shapeBkg_dataObs_cat1
#
# import (../data/_root/histos4combine_q2only_test.root,mu) -> shapeBkg_mu_cat1
#
# import (../data/_root/histos4combine_q2only_test.root,tau) -> shapeSig_tau_cat1
#
# RooWorkspace::factory('CMS_th1x[0,10]')
#  --->  <ROOT.RooRealVar object ("CMS_th1x") at 0x3a4cba0>
# RooWorkspace::factory('CMS_channel[cat1=0]')
#  --->  <ROOT.RooCategory object ("CMS_channel") at 0x6532ab0>
# recyling (cat1,dataObs,) -> shapeBkg_dataObs_cat1
#
# [#1] INFO:DataHandling -- RooDataHist::adjustBinning(shapeBkg_dataObs_cat1): fit range of variable CMS_th1x expanded to nearest bin boundaries: [0,10] --> [0,10]
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing dataset dataObs
# Created combined dataset with  10  entries, out of:
#   bin cat1 : entries =  recyling (cat1,dataObs,) -> shapeBkg_dataObs_cat1
#
# 10
# RooWorkspace::factory('r[1,0,20]')
#  --->  <ROOT.RooRealVar object ("r") at 0x87879f0>
# RooWorkspace::factory('MH[120]')
#  --->  <ROOT.RooRealVar object ("MH") at 0x87d4e00>
# RooWorkspace::factory('N_B2mu[1000,0,1]')
#  --->  <ROOT.RooRealVar object ("N_B2mu") at 0x88135b0>
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing ProcessNormalization::n_exp_bincat1_proc_mu
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing ProcessNormalization::n_exp_bincat1_proc_tau
# recyling (cat1,mu,) -> shapeBkg_mu_cat1
#
# recyling (cat1,mu,) -> shapeBkg_mu_cat1
#
# recyling (cat1,tau,) -> shapeSig_tau_cat1
#
# recyling (cat1,tau,) -> shapeSig_tau_cat1
#
# Creating RooAddPdf pdf_bincat1 with 2 elements
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooCategory::CMS_channel for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddPdf::pdf_bincat1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::CMS_th1x for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of ProcessNormalization::n_exp_bincat1_proc_mu for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::N_B2mu for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing FastVerticalInterpHistPdf2::shapeSig_tau_cat1_rebinPdf
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of ProcessNormalization::n_exp_bincat1_proc_tau for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::r for import of RooSimultaneousOpt::model_s
#
# === Using the following for ModelConfig ===
# Observables:             RooArgSet:: = (CMS_th1x,CMS_channel)
# Parameters of Interest:  RooArgSet:: = (r)
# PDF:                     RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
#
#
# RooWorkspace(w) w contents
#
# variables
# ---------
# (CMS_channel,CMS_th1x,MH,N_B2mu,r)
#
# p.d.f.s
# -------
# RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
#   RooAddPdf::pdf_bincat1[ n_exp_bincat1_proc_mu * shapeBkg_mu_cat1_rebinPdf + n_exp_bincat1_proc_tau * shapeSig_tau_cat1_rebinPdf ] = 0.119047
#     FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.0761978
#     FastVerticalInterpHistPdf2::shapeSig_tau_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.161897
#     ProcessNormalization::n_exp_bincat1_proc_mu[ thetaList=() asymmThetaList=() otherFactorList=(N_B2mu) ] = 1000
#     ProcessNormalization::n_exp_bincat1_proc_tau[ thetaList=() asymmThetaList=() otherFactorList=(r,N_B2mu) ] = 1000
#
# datasets
# --------
# RooDataSet::dataObs(CMS_th1x,CMS_channel)
#
# named sets
# ----------
# ModelConfig_Observables:(CMS_th1x,CMS_channel)
# ModelConfig_POI:(r)
# POI:(r)
# observables:(CMS_th1x,CMS_channel)
#
# generic objects
# ---------------
# RooStats::ModelConfig::ModelConfig
# RooArgSet::discreteParams
#
# Wrote GraphVizTree of model_s to  roostats-zhGRRR.root.dot
# Adding /afs/cern.ch/work/o/ocerri/CMSSW_10_2_3/src to include path
# Adding /cvmfs/cms.cern.ch/slc7_amd64_gcc700/lcg/root/6.12.07-gnimlf5//include to include path
# Input workspace 'w':
#
# RooWorkspace(w) w contents
#
# variables
# ---------
# (CMS_channel,CMS_th1x,MH,N_B2mu,r)
#
# p.d.f.s
# -------
# RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
# RooAddPdf::pdf_bincat1[ n_exp_bincat1_proc_mu * shapeBkg_mu_cat1_rebinPdf + n_exp_bincat1_proc_tau * shapeSig_tau_cat1_rebinPdf ] = 0.119047
# FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.0761978
# FastVerticalInterpHistPdf2::shapeSig_tau_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.161897
#
# functions
# --------
# ProcessNormalization::n_exp_bincat1_proc_mu[ thetaList=() asymmThetaList=() otherFactorList=(N_B2mu) ] = 1000
# ProcessNormalization::n_exp_bincat1_proc_tau[ thetaList=() asymmThetaList=() otherFactorList=(r,N_B2mu) ] = 1000
#
# datasets
# --------
# RooDataSet::dataObs(CMS_th1x,CMS_channel)
#
# named sets
# ----------
# ModelConfig_Observables:(CMS_th1x,CMS_channel)
# ModelConfig_POI:(r)
# POI:(r)
# observables:(CMS_th1x,CMS_channel)
#
# generic objects
# ---------------
# RooStats::ModelConfig::ModelConfig
# RooArgSet::discreteParams
#
# Workspace has a ModelConfig for signal called 'ModelConfig', with contents:
#
# === Using the following for ModelConfig ===
# Observables:             RooArgSet:: = (CMS_th1x,CMS_channel)
# Parameters of Interest:  RooArgSet:: = (r)
# PDF:                     RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
#
# Input ModelConfig 'ModelConfig':
#
# === Using the following for ModelConfig ===
# Observables:             RooArgSet:: = (CMS_th1x,CMS_channel)
# Parameters of Interest:  RooArgSet:: = (r)
# PDF:                     RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
#
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooSimultaneousOpt::_model_bonly_
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddPdf::pdf_bincat1__model_bonly_
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing ProcessNormalization::n_exp_bincat1_proc_tau__model_bonly_
# Set Range of Parameter r To : (0.001,1)
# Set Default Value of Parameter r To : 0.1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooUniform::prior
#  bin          CMS_th1x       CMS_channel    weight
#    0               0.5              cat1    13.0000000
#    1               1.5              cat1    19.0000000
#    2               2.5              cat1    69.0000000
#    3               3.5              cat1   108.0000000
#    4               4.5              cat1   135.0000000
#    5               5.5              cat1   173.0000000
#    6               6.5              cat1   174.0000000
#    7               7.5              cat1   203.0000000
#    8               8.5              cat1   174.0000000
#    9               9.5              cat1    99.0000000
# Parameters:
#   1) RooRealVar:: N_B2mu = 1000
#   2) RooRealVar::      r = 0.001
# Obs:
#   1) RooRealVar::    CMS_th1x = 9.5
#   2) RooCategory:: CMS_channel = cat1(idx = 0)
#
# do first Minimization
# Minuit2Minimizer: Minimize with max-calls 1000 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = -4.728567108558
# MnSeedGenerator: Initial state:   - FCN =  -4.728567108558 Edm =      285.387 NCalls =      9
# MnSeedGenerator: Negative G2 found - new state:   - FCN =   -140.941154952 Edm =      498.496 NCalls =     44
# VariableMetric: start iterating until Edm is < 9.88947e-05
# VariableMetric: Initial state   - FCN =   -140.941154952 Edm =      498.496 NCalls =     44
# VariableMetric: Iteration #   0 - FCN =   -140.941154952 Edm =      498.496 NCalls =     44
# VariableMetric: Iteration #   1 - FCN =  -239.4927723733 Edm =      29.5468 NCalls =     58
# VariableMetric: Iteration #   2 - FCN =  -246.6725139817 Edm =     0.506276 NCalls =     64
# VariableMetric: Iteration #   3 - FCN =  -248.1351164906 Edm =     0.177793 NCalls =     70
# VariableMetric: Iteration #   4 - FCN =   -248.416804615 Edm =   0.00183841 NCalls =     76
# VariableMetric: Iteration #   5 - FCN =  -248.4191929907 Edm =  1.32038e-06 NCalls =     82
# VariableMetric: After Hessian   - FCN =  -248.4191929907 Edm =  1.38596e-06 NCalls =     92
# VariableMetric: Iteration #   6 - FCN =  -248.4191929907 Edm =  1.38596e-06 NCalls =     92
# Number of iterations 7
# ----------> Iteration 0
#             FVAL = -140.941154952 Edm = 498.49587215 Nfcn = 44
#             Error matrix change = 1
#             Parameters :  p0 = 1000 p1 = 0.665208
# ----------> Iteration 1
#             FVAL = -239.492772373 Edm = 29.5468153567 Nfcn = 58
#             Error matrix change = 0.621628
#             Parameters :  p0 = 897.048 p1 = 0.148665
# ----------> Iteration 2
#             FVAL = -246.672513982 Edm = 0.506276284461 Nfcn = 64
# ----------> Iteration 3
#             FVAL = -248.135116491 Edm = 0.177792669116 Nfcn = 70
# ----------> Iteration 4
#             FVAL = -248.416804615 Edm = 0.00183840563317 Nfcn = 76
# ----------> Iteration 5
#             FVAL = -248.419192991 Edm = 1.32038340388e-06 Nfcn = 82
#             Error matrix change = 0.188137
#             Parameters :  p0 = 1052.16 p1 = 0.109199
# ----------> Iteration 6
#             FVAL = -248.419192991 Edm = 1.38595841233e-06 Nfcn = 92
#             Error matrix change = 0
#             Parameters :  p0 = 1052.16 p1 = 0.109199
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -248.419192990679562
# Edm   = 1.38595841233069655e-06
# Nfcn  = 92
# N_B2mu	  = 1052.16	 +/-  59.5563
# r	  = 0.109199	 +/-  0.0535404	(limited)
# Minimized in : Real time 0:00:00, CP time 0.060
# Minuit2Minimizer::Hesse  - State returned from Hesse
#
# # of function calls: 102
# function Value: -248.4191929907
# expected distance to the Minimum (edm): 1.385470702429e-06
# external parameters:
# # ext. ||   Name    ||   type  ||     Value     ||  Error +/-
#
#    0   ||    N_B2mu ||  free   ||      1052.160633906 ||59.47395786084
#    1   ||         r || limited ||      0.109198745474 ||0.05346709003343
#
#
#
# covariance matrix status: 3
# covariance matrix:
# MnUserCovariance:
#
#       3537.15     -2.73944
#      -2.73944   0.00288745
#
# MnUserCovariance Parameter correlations:
#
#             1    -0.857191
#     -0.857191            1
#
# global correlation coefficients :
# MnGlobalCorrelationCoeff:
#
#      0.857191
#      0.857191
#
#
#
#
#   RooFitResult: minimized FCN value: -248.419, estimated distance to minimum: 1.38547e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 N_B2mu    1.0000e+03    1.0522e+03 +/-  5.95e+01  <none>
#                      r    1.0000e+00    1.0920e-01 +/-  5.35e-02  <none>
#
# Robus Fit for POI
# Set default minimizer to Minuit2, algorithm Migrad, tolerance 0.1
# Searching for crossing at nll = -15.0432 in the interval 0.109199, 1
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =  1.30805e-06 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =  1.30805e-06 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =  1.30805e-06 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -1.308070013195e-06 Edm =  8.78022e-16 NCalls =      8
# VariableMetric: After Hessian   - FCN = -1.308070013195e-06 Edm =  8.37491e-16 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -1.308070013195e-06 Edm =  8.37491e-16 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 1.30805300046e-06 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1052.16
# ----------> Iteration 1
#             FVAL = -1.3080700132e-06 Edm = 8.78022423998e-16 Nfcn = 8
#             Error matrix change = 0.500013
#             Parameters :  p0 = 1052.11
# ----------> Iteration 2
#             FVAL = -1.3080700132e-06 Edm = 8.37490562729e-16 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1052.11
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -1.30807001319510618e-06
# Edm   = 8.3749056272863558e-16
# Nfcn  = 13
# N_B2mu	  = 1052.11	 +/-  30.7983
#       r      lvl-here  lvl-there   stepping
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =      3.76344 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =      3.76344 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =      3.76344 NCalls =      5
# VariableMetric: Iteration #   1 - FCN =  -3.571505553441 Edm =   0.00214612 NCalls =      9
# VariableMetric: Iteration #   2 - FCN =  -3.573340098753 Edm =  4.87408e-10 NCalls =     13
# VariableMetric: After Hessian   - FCN =  -3.573340098753 Edm =  4.51437e-10 NCalls =     18
# VariableMetric: Iteration #   3 - FCN =  -3.573340098753 Edm =  4.51437e-10 NCalls =     18
# Number of iterations 4
# ----------> Iteration 0
#             FVAL = 0 Edm = 3.76343548221 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1052.11
# ----------> Iteration 1
#             FVAL = -3.57150555344 Edm = 0.00214611892617 Nfcn = 9
#             Error matrix change = 0.541115
#             Parameters :  p0 = 972.171
# ----------> Iteration 2
#             FVAL = -3.57334009875 Edm = 4.87407664417e-10 Nfcn = 13
#             Error matrix change = 0.310713
#             Parameters :  p0 = 973.896
# ----------> Iteration 3
#             FVAL = -3.57334009875 Edm = 4.51436518402e-10 Nfcn = 18
#             Error matrix change = 0
#             Parameters :  p0 = 973.896
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -3.57334009875270553
# Edm   = 4.51436518401572006e-10
# Nfcn  = 18
# N_B2mu	  = 973.896	 +/-  28.5087
# 0.198279    -0.67013  +0.49447    0.089080
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =     0.338709 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =     0.338709 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =     0.338709 NCalls =      5
# VariableMetric: Iteration #   1 - FCN =  -0.333168002394 Edm =  0.000206451 NCalls =      8
# VariableMetric: Iteration #   2 - FCN = -0.3333645869583 Edm =  1.16814e-07 NCalls =     11
# VariableMetric: After Hessian   - FCN = -0.3333645869583 Edm =  1.14137e-07 NCalls =     16
# VariableMetric: Iteration #   3 - FCN = -0.3333645869583 Edm =  1.14137e-07 NCalls =     16
# Number of iterations 4
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.338708808129 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1052.11
# ----------> Iteration 1
#             FVAL = -0.333168002394 Edm = 0.000206451036347 Nfcn = 8
#             Error matrix change = 0.512344
#             Parameters :  p0 = 1026.76
# ----------> Iteration 2
#             FVAL = -0.333364586958 Edm = 1.16813989879e-07 Nfcn = 11
#             Error matrix change = 0.268212
#             Parameters :  p0 = 1027.37
# ----------> Iteration 3
#             FVAL = -0.333364586958 Edm = 1.1413749123e-07 Nfcn = 16
#             Error matrix change = 0
#             Parameters :  p0 = 1027.37
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.333364586958317943
# Edm   = 1.14137491230442016e-07
# Nfcn  = 16
# N_B2mu	  = 1027.37	 +/-  30.0742
# 0.135923    +0.37803  -0.67013    0.026724
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =     0.323352 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =     0.323352 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =     0.323352 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.3181862331661 Edm =  0.000187931 NCalls =      8
# VariableMetric: Iteration #   2 - FCN = -0.3183653874046 Edm =  1.01578e-07 NCalls =     11
# VariableMetric: After Hessian   - FCN = -0.3183653874046 Edm =  9.93003e-08 NCalls =     16
# VariableMetric: Iteration #   3 - FCN = -0.3183653874046 Edm =  9.93003e-08 NCalls =     16
# Number of iterations 4
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.323352115564 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1027.37
# ----------> Iteration 1
#             FVAL = -0.318186233166 Edm = 0.000187931268762 Nfcn = 8
#             Error matrix change = 0.512054
#             Parameters :  p0 = 1003.19
# ----------> Iteration 2
#             FVAL = -0.318365387405 Edm = 1.0157761793e-07 Nfcn = 11
#             Error matrix change = 0.267791
#             Parameters :  p0 = 1003.76
# ----------> Iteration 3
#             FVAL = -0.318365387405 Edm = 9.93003489404e-08 Nfcn = 16
#             Error matrix change = 0
#             Parameters :  p0 = 1003.76
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.318365387404572431
# Edm   = 9.93003489404335639e-08
# Nfcn  = 16
# N_B2mu	  = 1003.76	 +/-  29.3828
# 0.162647    +0.04949  +0.37803    0.026724
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =     0.308641 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =     0.308641 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =     0.308641 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.3038255269549 Edm =  0.000171041 NCalls =      8
# VariableMetric: Iteration #   2 - FCN = -0.3039887621421 Edm =  8.82958e-08 NCalls =     11
# VariableMetric: After Hessian   - FCN = -0.3039887621421 Edm =  8.63588e-08 NCalls =     16
# VariableMetric: Iteration #   3 - FCN = -0.3039887621421 Edm =  8.63588e-08 NCalls =     16
# Number of iterations 4
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.308641143596 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1003.76
# ----------> Iteration 1
#             FVAL = -0.303825526955 Edm = 0.000171041162195 Nfcn = 8
#             Error matrix change = 0.51177
#             Parameters :  p0 = 980.672
# ----------> Iteration 2
#             FVAL = -0.303988762142 Edm = 8.82958266033e-08 Nfcn = 11
#             Error matrix change = 0.267378
#             Parameters :  p0 = 981.203
# ----------> Iteration 3
#             FVAL = -0.303988762142 Edm = 8.63588164858e-08 Nfcn = 16
#             Error matrix change = 0
#             Parameters :  p0 = 981.203
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.303988762142145319
# Edm   = 8.63588164858300341e-08
# Nfcn  = 16
# N_B2mu	  = 981.203	 +/-  28.7226
# 0.189371    -0.46283  +0.04949    0.026724
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =    0.0278513 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =    0.0278513 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =    0.0278513 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.02772231515445 Edm =  1.34786e-06 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.02772231515445 Edm =   1.3293e-06 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.02772231515445 Edm =   1.3293e-06 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.0278512552487 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1003.76
# ----------> Iteration 1
#             FVAL = -0.0277223151544 Edm = 1.34785903661e-06 Nfcn = 8
#             Error matrix change = 0.503478
#             Parameters :  p0 = 996.823
# ----------> Iteration 2
#             FVAL = -0.0277223151544 Edm = 1.32929897094e-06 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 996.823
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.0277223151544454538
# Edm   = 1.3292989709404035e-06
# Nfcn  = 13
# N_B2mu	  = 996.823	 +/-  29.1798
# 0.170664    -0.08609  -0.46283    0.008017
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =   0.00252875 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =   0.00252875 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =   0.00252875 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.002525234834698 Edm =  1.09968e-08 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.002525234834698 Edm =  1.09509e-08 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.002525234834698 Edm =  1.09509e-08 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.00252874750188 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1003.76
# ----------> Iteration 1
#             FVAL = -0.0025252348347 Edm = 1.09968278507e-08 Nfcn = 8
#             Error matrix change = 0.501043
#             Parameters :  p0 = 1001.67
# ----------> Iteration 2
#             FVAL = -0.0025252348347 Edm = 1.09508606438e-08 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1001.67
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.00252523483469779819
# Edm   = 1.09508606438149615e-08
# Nfcn  = 13
# N_B2mu	  = 1001.67	 +/-  29.3217
# 0.165052    +0.01052  -0.08609    0.002405
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =   0.00247634 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =   0.00247634 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =   0.00247634 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.002472938113275 Edm =  1.05527e-08 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.002472938113275 Edm =   1.0509e-08 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.002472938113275 Edm =   1.0509e-08 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.0024763439028 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1001.67
# ----------> Iteration 1
#             FVAL = -0.00247293811328 Edm = 1.0552704605e-08 Nfcn = 8
#             Error matrix change = 0.501032
#             Parameters :  p0 = 999.604
# ----------> Iteration 2
#             FVAL = -0.00247293811328 Edm = 1.05090180854e-08 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 999.604
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.00247293811327509161
# Edm   = 1.05090180853783477e-08
# Nfcn  = 13
# N_B2mu	  = 999.604	 +/-  29.2611
# 0.167457    -0.02992  +0.01052    0.002405
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =  0.000220689 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =  0.000220689 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =  0.000220689 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.0002205986900154 Edm =  8.37742e-11 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.0002205986900154 Edm =   8.3618e-11 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.0002205986900154 Edm =   8.3618e-11 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.000220689250346 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1001.67
# ----------> Iteration 1
#             FVAL = -0.000220598690015 Edm = 8.37741947913e-11 Nfcn = 8
#             Error matrix change = 0.500308
#             Parameters :  p0 = 1001.05
# ----------> Iteration 2
#             FVAL = -0.000220598690015 Edm = 8.36179913027e-11 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1001.05
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.000220598690015449961
# Edm   = 8.36179913027351551e-11
# Nfcn  = 13
# N_B2mu	  = 1001.05	 +/-  29.3036
# 0.165774    -0.00146  -0.02992    0.000722
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =  1.92144e-05 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =  1.92144e-05 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =  1.92144e-05 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -1.921214524181e-05 Edm =    6.167e-13 NCalls =      8
# VariableMetric: After Hessian   - FCN = -1.921214524181e-05 Edm =  6.14779e-13 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -1.921214524181e-05 Edm =  6.14779e-13 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 1.92143864897e-05 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1001.67
# ----------> Iteration 1
#             FVAL = -1.92121452418e-05 Edm = 6.16700241426e-13 Nfcn = 8
#             Error matrix change = 0.50009
#             Parameters :  p0 = 1001.49
# ----------> Iteration 2
#             FVAL = -1.92121452418e-05 Edm = 6.14778822423e-13 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1001.49
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -1.92121452418092531e-05
# Edm   = 6.14778822422700354e-13
# Nfcn  = 13
# N_B2mu	  = 1001.49	 +/-  29.3163
# 0.165268    +0.00694  -0.00146    0.000216
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =  2.01284e-05 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =  2.01284e-05 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =  2.01284e-05 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -2.01260077386e-05 Edm =  6.83185e-13 NCalls =      8
# VariableMetric: After Hessian   - FCN = -2.01260077386e-05 Edm =  6.82432e-13 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -2.01260077386e-05 Edm =  6.82432e-13 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 2.01284324167e-05 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1001.49
# ----------> Iteration 1
#             FVAL = -2.01260077386e-05 Edm = 6.83184779952e-13 Nfcn = 8
#             Error matrix change = 0.500092
#             Parameters :  p0 = 1001.3
# ----------> Iteration 2
#             FVAL = -2.01260077386e-05 Edm = 6.82431741913e-13 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1001.3
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -2.01260077385967406e-05
# Edm   = 6.82431741912524543e-13
# Nfcn  = 13
# N_B2mu	  = 1001.3	 +/-  29.3109
# 0.165485    +0.00335  +0.00694    0.000216
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =  2.01206e-05 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =  2.01206e-05 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =  2.01206e-05 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -2.011815739777e-05 Edm =  6.79363e-13 NCalls =      8
# VariableMetric: After Hessian   - FCN = -2.011815739777e-05 Edm =  6.74801e-13 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -2.011815739777e-05 Edm =  6.74801e-13 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 2.01205725852e-05 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1001.3
# ----------> Iteration 1
#             FVAL = -2.01181573978e-05 Edm = 6.79362867444e-13 Nfcn = 8
#             Error matrix change = 0.500092
#             Parameters :  p0 = 1001.11
# ----------> Iteration 2
#             FVAL = -2.01181573978e-05 Edm = 6.74801326968e-13 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1001.11
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -2.0118157397774894e-05
# Edm   = 6.74801326967931006e-13
# Nfcn  = 13
# N_B2mu	  = 1001.11	 +/-  29.3054
# 0.165701    -0.00026  +0.00335    0.000216
# Set default minimizer to Minuit2, algorithm Migrad, tolerance 0.1
# Searching for crossing at nll = -15.0432 in the interval 0.109199, 0.001
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =  1.30805e-06 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =  1.30805e-06 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =  1.30805e-06 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -1.308070013195e-06 Edm =  8.78022e-16 NCalls =      8
# VariableMetric: After Hessian   - FCN = -1.308070013195e-06 Edm =  8.37491e-16 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -1.308070013195e-06 Edm =  8.37491e-16 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 1.30805300046e-06 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1052.16
# ----------> Iteration 1
#             FVAL = -1.3080700132e-06 Edm = 8.78022423998e-16 Nfcn = 8
#             Error matrix change = 0.500013
#             Parameters :  p0 = 1052.11
# ----------> Iteration 2
#             FVAL = -1.3080700132e-06 Edm = 8.37490562729e-16 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1052.11
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -1.30807001319510618e-06
# Edm   = 8.3749056272863558e-16
# Nfcn  = 13
# N_B2mu	  = 1052.11	 +/-  30.7983
#       r      lvl-here  lvl-there   stepping
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =    0.0555221 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =    0.0555221 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =    0.0555221 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.05588064721593 Edm =  5.18342e-06 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.05588064721593 Edm =  5.28503e-06 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.05588064721593 Edm =  5.28503e-06 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.0555221062034 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1052.11
# ----------> Iteration 1
#             FVAL = -0.0558806472159 Edm = 5.1834192701e-06 Nfcn = 8
#             Error matrix change = 0.504831
#             Parameters :  p0 = 1062.37
# ----------> Iteration 2
#             FVAL = -0.0558806472159 Edm = 5.2850334295e-06 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1062.37
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.0558806472159254497
# Edm   = 5.28503342950318865e-06
# Nfcn  = 13
# N_B2mu	  = 1062.37	 +/-  31.0986
# 0.098379    +0.47393  +0.49447    -0.010820
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =    0.0577099 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =    0.0577099 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =    0.0577099 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.05808970857079 Edm =  5.59544e-06 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.05808970857079 Edm =  5.70727e-06 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.05808970857079 Edm =  5.70727e-06 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.057709945172 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1062.37
# ----------> Iteration 1
#             FVAL = -0.0580897085708 Edm = 5.59544099921e-06 Nfcn = 8
#             Error matrix change = 0.504923
#             Parameters :  p0 = 1072.94
# ----------> Iteration 2
#             FVAL = -0.0580897085708 Edm = 5.70726937992e-06 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1072.94
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.0580897085707867689
# Edm   = 5.70726937992059476e-06
# Nfcn  = 13
# N_B2mu	  = 1072.94	 +/-  31.408
# 0.087559    +0.41082  +0.47393    -0.010820
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =    0.0588961 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =    0.0588961 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =    0.0588961 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.05928762189282 Edm =  5.82665e-06 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.05928762189282 Edm =  5.94433e-06 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.05928762189282 Edm =  5.94433e-06 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.058896119541 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1072.94
# ----------> Iteration 1
#             FVAL = -0.0592876218928 Edm = 5.82665125739e-06 Nfcn = 8
#             Error matrix change = 0.504973
#             Parameters :  p0 = 1083.72
# ----------> Iteration 2
#             FVAL = -0.0592876218928 Edm = 5.9443252746e-06 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1083.72
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.0592876218928228838
# Edm   = 5.94432527460423009e-06
# Nfcn  = 13
# N_B2mu	  = 1083.72	 +/-  31.7236
# 0.076739    +0.30252  +0.41082    -0.010820
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =    0.0600977 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =    0.0600977 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =    0.0600977 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.06050130714553 Edm =  6.06658e-06 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.06050130714553 Edm =  6.19035e-06 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.06050130714553 Edm =  6.19035e-06 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.0600977443842 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1083.72
# ----------> Iteration 1
#             FVAL = -0.0605013071455 Edm = 6.06657653585e-06 Nfcn = 8
#             Error matrix change = 0.505024
#             Parameters :  p0 = 1094.72
# ----------> Iteration 2
#             FVAL = -0.0605013071455 Edm = 6.19035192816e-06 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1094.72
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.0605013071455324791
# Edm   = 6.19035192815524436e-06
# Nfcn  = 13
# N_B2mu	  = 1094.72	 +/-  32.0455
# 0.065919    +0.14623  +0.30252    -0.010820
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =    0.0613363 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =    0.0613363 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =    0.0613363 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.06175230937945 Edm =  6.31626e-06 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.06175230937945 Edm =  6.44643e-06 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.06175230937945 Edm =  6.44643e-06 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.0613363206712 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1094.72
# ----------> Iteration 1
#             FVAL = -0.0617523093795 Edm = 6.31626020765e-06 Nfcn = 8
#             Error matrix change = 0.505074
#             Parameters :  p0 = 1105.94
# ----------> Iteration 2
#             FVAL = -0.0617523093795 Edm = 6.44643227345e-06 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1105.94
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.0617523093794503097
# Edm   = 6.44643227345111311e-06
# Nfcn  = 13
# N_B2mu	  = 1105.94	 +/-  32.374
# 0.055099    -0.06103  +0.14623    -0.010820
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =    0.0057821 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =    0.0057821 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =    0.0057821 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.005794203241857 Edm =  5.69122e-08 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.005794203241857 Edm =  5.72682e-08 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.005794203241857 Edm =  5.72682e-08 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.00578210214706 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1094.72
# ----------> Iteration 1
#             FVAL = -0.00579420324186 Edm = 5.69122196875e-08 Nfcn = 8
#             Error matrix change = 0.501569
#             Parameters :  p0 = 1098.16
# ----------> Iteration 2
#             FVAL = -0.00579420324186 Edm = 5.72682415645e-08 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1098.16
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.00579420324185697666
# Edm   = 5.72682415644569999e-08
# Nfcn  = 13
# N_B2mu	  = 1098.16	 +/-  32.1463
# 0.062673    +0.08955  -0.06103    -0.003246
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =    0.0054794 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =    0.0054794 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =    0.0054794 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.005490560244491 Edm =  5.10933e-08 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.005490560244491 Edm =  5.14062e-08 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.005490560244491 Edm =  5.14062e-08 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.00547940027727 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1098.16
# ----------> Iteration 1
#             FVAL = -0.00549056024449 Edm = 5.10932668341e-08 Nfcn = 8
#             Error matrix change = 0.501527
#             Parameters :  p0 = 1101.53
# ----------> Iteration 2
#             FVAL = -0.00549056024449 Edm = 5.14062171113e-08 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1101.53
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.00549056024449079416
# Edm   = 5.14062171112785401e-08
# Nfcn  = 13
# N_B2mu	  = 1101.53	 +/-  32.2448
# 0.059427    +0.02820  +0.08955    -0.003246
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =   0.00551105 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =   0.00551105 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =   0.00551105 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.005522313293941 Edm =  5.17469e-08 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.005522313293941 Edm =  5.20649e-08 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.005522313293941 Edm =  5.20649e-08 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.00551104633911 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1101.53
# ----------> Iteration 1
#             FVAL = -0.00552231329394 Edm = 5.17468824369e-08 Nfcn = 8
#             Error matrix change = 0.501532
#             Parameters :  p0 = 1104.91
# ----------> Iteration 2
#             FVAL = -0.00552231329394 Edm = 5.20649053453e-08 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1104.91
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.00552231329394103909
# Edm   = 5.20649053453120883e-08
# Nfcn  = 13
# N_B2mu	  = 1104.91	 +/-  32.3439
# 0.056181    -0.03791  +0.02820    -0.003246
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =   0.00050309 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =   0.00050309 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =   0.00050309 NCalls =      5
# VariableMetric: Iteration #   1 - FCN = -0.0005033999776103 Edm =  4.31892e-10 NCalls =      8
# VariableMetric: After Hessian   - FCN = -0.0005033999776103 Edm =  4.32574e-10 NCalls =     13
# VariableMetric: Iteration #   2 - FCN = -0.0005033999776103 Edm =  4.32574e-10 NCalls =     13
# Number of iterations 3
# ----------> Iteration 0
#             FVAL = 0 Edm = 0.00050308953458 Nfcn = 5
#             Error matrix change = 1
#             Parameters :  p0 = 1101.53
# ----------> Iteration 1
#             FVAL = -0.00050339997761 Edm = 4.31892112644e-10 Nfcn = 8
#             Error matrix change = 0.500463
#             Parameters :  p0 = 1102.55
# ----------> Iteration 2
#             FVAL = -0.00050339997761 Edm = 4.32573901915e-10 Nfcn = 13
#             Error matrix change = 0
#             Parameters :  p0 = 1102.55
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -0.000503399977610285987
# Edm   = 4.32573901915300508e-10
# Nfcn  = 13
# N_B2mu	  = 1102.55	 +/-  32.2748
# 0.058454    +0.00887  -0.03791    -0.000974
# Minuit2Minimizer: Minimize with max-calls 500 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =  0.000494811 NCalls =      5
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =  0.000494811 NCalls =      5
# VariableMetric: Iteration #   0 - FCN =                0 Edm =  0.000494811 NCalls =      5
# ...
#     (0x8d41060,V-) ProcessNormalization::n_exp_bincat1_proc_tau ""
#   Proxies:
#     !refCoefNorm ->
#     !refCoefNorm ->
#     !pdfs ->
#       1)   shapeBkg_mu_cat1_rebinPdf
#       2)  shapeSig_tau_cat1_rebinPdf
#     !coefficients ->
#       1)   n_exp_bincat1_proc_mu
#       2)  n_exp_bincat1_proc_tau
# --- RooAbsReal ---
#
#   Plot label is "pdf_bincat1"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore cat1 (cat1)
#   Contains 10 entries
#   Observables:
#     1)  CMS_th1x = 9.5  L(0 - 10) B(10)  "CMS_th1x"
#     2)    weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(pdf_bincat1) directly selected PDF components: (shapeSig_tau_cat1_rebinPdf)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(pdf_bincat1) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(pdf_bincat1) directly selected PDF components: (shapeSig_tau_cat1_rebinPdf)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(pdf_bincat1) indirectly selected PDF components: ()
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(pdf_bincat1) directly selected PDF components: (shapeBkg_mu_cat1_rebinPdf)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(pdf_bincat1) indirectly selected PDF components: ()
# [utils::makePlots] Number of events for pdf in cat1_CMS_th1x, pdf pdf_bincat1 = 1167.06
#
#  --- FitDiagnostics ---
# Best fit r: 0.109199  -0.050991/+0.0562647  (68% CL)
# Done in 0.01 min (cpu), 0.01 min (real)
# Printing Message Summary From ... combine_logger.out
# ----------------------------------------------
# Messages of type INFO : 124
# Messages of type DEBUG : 1
# Messages of type ERROR : 0
# ----------------------------------------------
# INFO: (function: applyOptionsBase) FitterAlgoBase.cc: 112 -- Setting robust fit options to Tolerance=0.1 / Strategy=0 / Type,Algo=Minuit2,Migrad (note that defaults of CascadeMinimizer were taken where option not specified)
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: doFit) FitterAlgoBase.cc: 334 -- Running RobustFit for POI r. Configured with strategy 0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 380 -- Searching for crossing at nll = -15.0432, in the interval 0.109199 < r < 1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 401 -- r lvl-here lvl-there 	stepping
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.198279    -0.67013  +0.49447    0.089080
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.135923    +0.37803  -0.67013    0.026724
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.162647    +0.04949  +0.37803    0.026724
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.189371    -0.46283  +0.04949    0.026724
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.170664    -0.08609  -0.46283    0.008017
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.165052    +0.01052  -0.08609    0.002405
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.167457    -0.02992  +0.01052    0.002405
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.165774    -0.00146  -0.02992    0.000722
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.165268    +0.00694  -0.00146    0.000216
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.165485    +0.00335  +0.00694    0.000216
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.165701    -0.00026  +0.00335    0.000216
# INFO: (function: findCrossing) FitterAlgoBase.cc: 380 -- Searching for crossing at nll = -15.0432, in the interval 0.109199 < r < 0.001
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 401 -- r lvl-here lvl-there 	stepping
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.098379    +0.47393  +0.49447    -0.010820
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.087559    +0.41082  +0.47393    -0.010820
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.076739    +0.30252  +0.41082    -0.010820
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.065919    +0.14623  +0.30252    -0.010820
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.055099    -0.06103  +0.14623    -0.010820
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.062673    +0.08955  -0.06103    -0.003246
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.059427    +0.02820  +0.08955    -0.003246
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.056181    -0.03791  +0.02820    -0.003246
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.058454    +0.00887  -0.03791    -0.000974
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.057480    -0.01089  +0.00887    -0.000974
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.058161    +0.00298  -0.01089    -0.000292
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.057869    -0.00294  +0.00298    -0.000292
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.058074    +0.00121  -0.00294    -0.000088
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.057986    -0.00056  +0.00121    -0.000088
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.058047    +0.00068  -0.00056    -0.000026
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: findCrossing) FitterAlgoBase.cc: 434 -- 0.058021    +0.00015  +0.00068    -0.000026
# DEBUG: (function: runSpecific) FitDiagnostics.cc: 412 -- Fit S+B, status = 0, numBadNLL = 0, covariance quality = 3
# INFO: (function: getNormalizations) FitDiagnostics.cc: 777 -- Generating toy data for evaluating per-bin uncertainties and covariances with post-fit nuisance parameters with 200 toys
# Using shapes: qui si parra' la tua nobilitate
# Will use binning variable CMS_th1x with 10 bins
# Will use category 'CMS_channel' to identify the 1 channels
# done.
# Importing combined pdf model_s
# Setting variable 'MH' in workspace to the higgs mass 120
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-zhGRRR.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
# PDF didn't factorize!
# Info in <Minuit2>: Minuit2Minimizer::Hesse : Hesse is valid - matrix is accurate
# Error in <TList::Clear>: A list is accessing an object (0x8d76f74) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file results/q2only_test/cat1_CMS_th1x_fit_s.png has been created
# Info in <TCanvas::Print>: png file results/q2only_test/covariance_fit_s.png has been created

# %% [markdown]
# ### Run the Goodness of fit test

# %% [markdown]
# Run the observed test stat value

# %%
cmd = 'combine'
cmd += ' -M GoodnessOfFit'
cmd += ' -d ' + card_location
cmd += ' -D ' + histo['data'].GetName()
cmd += ' -n Obs'                                    # Just the output name
cmd += ' -t 0'                                      # Don't run toys
cmd += ' -s -1'                                     # Random seed
cmd += ' --toysFrequentist --algo=saturated'
cmd += ' --setParameters r=0.1'
cmd += ' --setParameterRanges r=0.001,1'
cmd += ' --trackParameters N_B2mu'
cmd += ' --plots'
cmd += ' --verbose 9'

# %%
print cmd
os.system(cmd)
# Out:
# combine -M GoodnessOfFit -d cards/q2only_test.txt -D dataObs -n Obs -t 0 -s -1 --toysFrequentist --algo=saturated --setParameters r=0.1 --setParameterRanges r=0.001,1 --trackParameters N_B2mu --plots --verbose 9
# 0
# Will use saturated models to compute goodness of fit for a binned likelihood
# >>> method used is GoodnessOfFit
# >>> Using OpenSSL to get a really random seed
# >>> Used OpenSSL to get a really random seed -1642788361
# import (../data/_root/histos4combine_q2only_test.root,dataObs) -> shapeBkg_dataObs_cat1
#
# import (../data/_root/histos4combine_q2only_test.root,mu) -> shapeBkg_mu_cat1
#
# import (../data/_root/histos4combine_q2only_test.root,tau) -> shapeSig_tau_cat1
#
# RooWorkspace::factory('CMS_th1x[0,10]')
#  --->  <ROOT.RooRealVar object ("CMS_th1x") at 0x4709240>
# RooWorkspace::factory('CMS_channel[cat1=0]')
#  --->  <ROOT.RooCategory object ("CMS_channel") at 0x71d4580>
# recyling (cat1,dataObs,) -> shapeBkg_dataObs_cat1
#
# [#1] INFO:DataHandling -- RooDataHist::adjustBinning(shapeBkg_dataObs_cat1): fit range of variable CMS_th1x expanded to nearest bin boundaries: [0,10] --> [0,10]
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing dataset dataObs
# Created combined dataset with  10  entries, out of:
#   bin cat1 : entries =  recyling (cat1,dataObs,) -> shapeBkg_dataObs_cat1
#
# 10
# RooWorkspace::factory('r[1,0,20]')
#  --->  <ROOT.RooRealVar object ("r") at 0x9412900>
# RooWorkspace::factory('MH[120]')
#  --->  <ROOT.RooRealVar object ("MH") at 0x94afd20>
# RooWorkspace::factory('N_B2mu[1000,0,1]')
#  --->  <ROOT.RooRealVar object ("N_B2mu") at 0x94ef290>
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing ProcessNormalization::n_exp_bincat1_proc_mu
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing ProcessNormalization::n_exp_bincat1_proc_tau
# recyling (cat1,mu,) -> shapeBkg_mu_cat1
#
# recyling (cat1,mu,) -> shapeBkg_mu_cat1
#
# recyling (cat1,tau,) -> shapeSig_tau_cat1
#
# recyling (cat1,tau,) -> shapeSig_tau_cat1
#
# Creating RooAddPdf pdf_bincat1 with 2 elements
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooCategory::CMS_channel for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddPdf::pdf_bincat1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::CMS_th1x for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of ProcessNormalization::n_exp_bincat1_proc_mu for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::N_B2mu for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing FastVerticalInterpHistPdf2::shapeSig_tau_cat1_rebinPdf
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of ProcessNormalization::n_exp_bincat1_proc_tau for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::r for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooSimultaneousOpt::model_b
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooCategory::CMS_channel for import of RooSimultaneousOpt::model_b
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddPdf::pdf_bincat1_bonly
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf for import of RooSimultaneousOpt::model_b
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::CMS_th1x for import of RooSimultaneousOpt::model_b
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of ProcessNormalization::n_exp_bincat1_proc_mu for import of RooSimultaneousOpt::model_b
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::N_B2mu for import of RooSimultaneousOpt::model_b
#
# === Using the following for ModelConfig ===
# Observables:             RooArgSet:: = (CMS_th1x,CMS_channel)
# Parameters of Interest:  RooArgSet:: = (r)
# PDF:                     RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
#
#
# === Using the following for ModelConfig_bonly ===
# Observables:             RooArgSet:: = (CMS_th1x,CMS_channel)
# Parameters of Interest:  RooArgSet:: = (r)
# PDF:                     RooSimultaneousOpt::model_b[ indexCat=CMS_channel cat1=pdf_bincat1_bonly extraConstraints=() channelMasks=() ] = 0.0761978
#
#
# RooWorkspace(w) w contents
#
# variables
# ---------
# (CMS_channel,CMS_th1x,MH,N_B2mu,r)
#
# p.d.f.s
# -------
# RooSimultaneousOpt::model_b[ indexCat=CMS_channel cat1=pdf_bincat1_bonly extraConstraints=() channelMasks=() ] = 0.0761978
#   RooAddPdf::pdf_bincat1_bonly[ n_exp_bincat1_proc_mu * shapeBkg_mu_cat1_rebinPdf ] = 0.0761978
#     FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.0761978
#     ProcessNormalization::n_exp_bincat1_proc_mu[ thetaList=() asymmThetaList=() otherFactorList=(N_B2mu) ] = 1000
# RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
#   RooAddPdf::pdf_bincat1[ n_exp_bincat1_proc_mu * shapeBkg_mu_cat1_rebinPdf + n_exp_bincat1_proc_tau * shapeSig_tau_cat1_rebinPdf ] = 0.119047
#     FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.0761978
#     FastVerticalInterpHistPdf2::shapeSig_tau_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.161897
#     ProcessNormalization::n_exp_bincat1_proc_mu[ thetaList=() asymmThetaList=() otherFactorList=(N_B2mu) ] = 1000
#     ProcessNormalization::n_exp_bincat1_proc_tau[ thetaList=() asymmThetaList=() otherFactorList=(r,N_B2mu) ] = 1000
#
# datasets
# --------
# RooDataSet::dataObs(CMS_th1x,CMS_channel)
#
# named sets
# ----------
# ModelConfig_Observables:(CMS_th1x,CMS_channel)
# ModelConfig_POI:(r)
# ModelConfig_bonly_Observables:(CMS_th1x,CMS_channel)
# ModelConfig_bonly_POI:(r)
# POI:(r)
# observables:(CMS_th1x,CMS_channel)
#
# generic objects
# ---------------
# RooStats::ModelConfig::ModelConfig
# RooStats::ModelConfig::ModelConfig_bonly
# RooArgSet::discreteParams
#
# Wrote GraphVizTree of model_s to  roostats-oFhlEx.root.dot
# Adding /afs/cern.ch/work/o/ocerri/CMSSW_10_2_3/src to include path
# Adding /cvmfs/cms.cern.ch/slc7_amd64_gcc700/lcg/root/6.12.07-gnimlf5//include to include path
# Input workspace 'w':
#
# RooWorkspace(w) w contents
#
# variables
# ---------
# (CMS_channel,CMS_th1x,MH,N_B2mu,r)
#
# p.d.f.s
# -------
# RooSimultaneousOpt::model_b[ indexCat=CMS_channel cat1=pdf_bincat1_bonly extraConstraints=() channelMasks=() ] = 0.0761978
# RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
# RooAddPdf::pdf_bincat1[ n_exp_bincat1_proc_mu * shapeBkg_mu_cat1_rebinPdf + n_exp_bincat1_proc_tau * shapeSig_tau_cat1_rebinPdf ] = 0.119047
# RooAddPdf::pdf_bincat1_bonly[ n_exp_bincat1_proc_mu * shapeBkg_mu_cat1_rebinPdf ] = 0.0761978
# FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.0761978
# FastVerticalInterpHistPdf2::shapeSig_tau_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.161897
#
# functions
# --------
# ProcessNormalization::n_exp_bincat1_proc_mu[ thetaList=() asymmThetaList=() otherFactorList=(N_B2mu) ] = 1000
# ProcessNormalization::n_exp_bincat1_proc_tau[ thetaList=() asymmThetaList=() otherFactorList=(r,N_B2mu) ] = 1000
#
# datasets
# --------
# RooDataSet::dataObs(CMS_th1x,CMS_channel)
#
# named sets
# ----------
# ModelConfig_Observables:(CMS_th1x,CMS_channel)
# ModelConfig_POI:(r)
# ModelConfig_bonly_Observables:(CMS_th1x,CMS_channel)
# ModelConfig_bonly_POI:(r)
# POI:(r)
# observables:(CMS_th1x,CMS_channel)
#
# generic objects
# ---------------
# RooStats::ModelConfig::ModelConfig
# RooStats::ModelConfig::ModelConfig_bonly
# RooArgSet::discreteParams
#
# Workspace has a ModelConfig for signal called 'ModelConfig', with contents:
#
# === Using the following for ModelConfig ===
# Observables:             RooArgSet:: = (CMS_th1x,CMS_channel)
# Parameters of Interest:  RooArgSet:: = (r)
# PDF:                     RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
#
# Input ModelConfig 'ModelConfig':
#
# === Using the following for ModelConfig ===
# Observables:             RooArgSet:: = (CMS_th1x,CMS_channel)
# Parameters of Interest:  RooArgSet:: = (r)
# PDF:                     RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
#
# Set Range of Parameter r To : (0.001,1)
# Set Default Value of Parameter r To : 0.1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooUniform::prior
#  bin          CMS_th1x       CMS_channel    weight
#    0               0.5              cat1    13.0000000
#    1               1.5              cat1    19.0000000
#    2               2.5              cat1    69.0000000
#    3               3.5              cat1   108.0000000
#    4               4.5              cat1   135.0000000
#    5               5.5              cat1   173.0000000
#    6               6.5              cat1   174.0000000
#    7               7.5              cat1   203.0000000
#    8               8.5              cat1   174.0000000
#    9               9.5              cat1    99.0000000
# Generating saturated model for cat1
#  bin          CMS_th1x    weight
#    0               0.5    13.0000000
#    1               1.5    19.0000000
#    2               2.5    69.0000000
#    3               3.5   108.0000000
#    4               4.5   135.0000000
#    5               5.5   173.0000000
#    6               6.5   174.0000000
#    7               7.5   203.0000000
#    8               8.5   174.0000000
#    9               9.5    99.0000000
# Parameters:
#   1) RooRealVar:: N_B2mu = 1000
#   2) RooRealVar::      r = 0.1
# Obs:
#   1) RooRealVar::    CMS_th1x = 9.5
#   2) RooCategory:: CMS_channel = cat1(idx = 0)
#
# Parameters:
# Obs:
#   1) RooRealVar::    CMS_th1x = 9.5
#   2) RooCategory:: CMS_channel = cat1(idx = 0)
#
# Minuit2Minimizer: Minimize with max-calls 1000 convergence for edm < 0.1 strategy 1
# Minuit2Minimizer::Minuit  - Changing default options
#              StorageLevel :               0
# MnSeedGenerator: for initial parameters FCN = 0
# MnSeedGenerator: Initial state:   - FCN =                0 Edm =      3.90848 NCalls =      9
# VariableMetric: start iterating until Edm is < 0.0001
# VariableMetric: Initial state   - FCN =                0 Edm =      3.90848 NCalls =      9
# VariableMetric: Iteration #   0 - FCN =                0 Edm =      3.90848 NCalls =      9
# VariableMetric: Iteration #   1 - FCN =  -1.923139314251 Edm =    0.0168569 NCalls =     15
# VariableMetric: Iteration #   2 - FCN =  -1.993598437344 Edm =    0.0157028 NCalls =     21
# VariableMetric: Iteration #   3 - FCN =  -2.015041968585 Edm =  9.04809e-06 NCalls =     27
# VariableMetric: After Hessian   - FCN =  -2.015041968585 Edm =  1.25025e-05 NCalls =     37
# VariableMetric: Iteration #   4 - FCN =  -2.015041968585 Edm =  1.25025e-05 NCalls =     37
# Number of iterations 5
# ----------> Iteration 0
#             FVAL = 0 Edm = 3.90848212584 Nfcn = 9
#             Error matrix change = 1
#             Parameters :  p0 = 1000 p1 = 0.1
# ----------> Iteration 1
#             FVAL = -1.92313931425 Edm = 0.0168568891268 Nfcn = 15
#             Error matrix change = 0.622697
#             Parameters :  p0 = 1026.71 p1 = 0.13061
# ----------> Iteration 2
#             FVAL = -1.99359843734 Edm = 0.0157028379568 Nfcn = 21
# ----------> Iteration 3
#             FVAL = -2.01504196858 Edm = 9.04808829545e-06 Nfcn = 27
#             Error matrix change = 0.375389
#             Parameters :  p0 = 1052.04 p1 = 0.109397
# ----------> Iteration 4
#             FVAL = -2.01504196858 Edm = 1.25024891892e-05 Nfcn = 37
#             Error matrix change = 0
#             Parameters :  p0 = 1052.04 p1 = 0.109397
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -2.01504196858459306
# Edm   = 1.25024891892244322e-05
# Nfcn  = 37
# N_B2mu	  = 1052.04	 +/-  59.7793
# r	  = 0.109397	 +/-  0.0537487	(limited)
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 5.05871
# Done in 0.00 min (cpu), 0.00 min (real)
# Printing Message Summary From ... combine_logger.out
# ----------------------------------------------
# Messages of type INFO : 5
# Messages of type DEBUG : 1
# Messages of type ERROR : 0
# ----------------------------------------------
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=-1
# DEBUG: (function: improveOnce) CascadeMinimizer.cc: 196 -- Minimization ended with latest status != 0 or 1
# Using shapes: qui si parra' la tua nobilitate
# Will use binning variable CMS_th1x with 10 bins
# Will use category 'CMS_channel' to identify the 1 channels
# done.
# Importing combined pdf model_s
# Importing combined pdf model_b
# Setting variable 'MH' in workspace to the higgs mass 120
# RooSimultaneousOpt: number of channel masks must equal number of channels
# PDF didn't factorize!
# PDF didn't factorize!
# Error in <ROOT::Math::Fitter::SetFCN>: FCN function has zero parameters

# %% [markdown]
# Run the test stat toy distribution

# %%
cmd = 'combine'
cmd += ' -M GoodnessOfFit'
cmd += ' -d ' + card_location
cmd += ' -D ' + histo['data'].GetName()
cmd += ' -n Toys'                                   # Just the output name
cmd += ' -t 100'                                    # Number of toys to run
cmd += ' -s -1'                                     # Random seed
cmd += ' --toysFrequentist --algo=saturated'
# cmd += '--expectSignal=0'                           # Depending on the hypothesis to test. If none, r is fluctruated
cmd += ' --setParameters r=0.1'
cmd += ' --setParameterRanges r=0.001,1'
cmd += ' --trackParameters N_B2mu'
cmd += ' --plots'
cmd += ' --verbose 9'

# %%
print cmd
os.system(cmd)
# Out:
# combine -M GoodnessOfFit -d cards/q2only_test.txt -D dataObs -n Toys -t 100 -s -1 --toysFrequentist --algo=saturated --setParameters r=0.1 --setParameterRanges r=0.001,1 --trackParameters N_B2mu --plots --verbose 9
# 47360
# Will use saturated models to compute goodness of fit for a binned likelihood
# >>> method used is GoodnessOfFit
# >>> Using OpenSSL to get a really random seed
# >>> Used OpenSSL to get a really random seed 1295348221
# import (../data/_root/histos4combine_q2only_test.root,dataObs) -> shapeBkg_dataObs_cat1
#
# import (../data/_root/histos4combine_q2only_test.root,mu) -> shapeBkg_mu_cat1
#
# import (../data/_root/histos4combine_q2only_test.root,tau) -> shapeSig_tau_cat1
#
# RooWorkspace::factory('CMS_th1x[0,10]')
#  --->  <ROOT.RooRealVar object ("CMS_th1x") at 0x3b93ae0>
# RooWorkspace::factory('CMS_channel[cat1=0]')
#  --->  <ROOT.RooCategory object ("CMS_channel") at 0x6649040>
# recyling (cat1,dataObs,) -> shapeBkg_dataObs_cat1
#
# [#1] INFO:DataHandling -- RooDataHist::adjustBinning(shapeBkg_dataObs_cat1): fit range of variable CMS_th1x expanded to nearest bin boundaries: [0,10] --> [0,10]
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing dataset dataObs
# Created combined dataset with  10  entries, out of:
#   bin cat1 : entries =  recyling (cat1,dataObs,) -> shapeBkg_dataObs_cat1
#
# 10
# RooWorkspace::factory('r[1,0,20]')
#  --->  <ROOT.RooRealVar object ("r") at 0x3419710>
# RooWorkspace::factory('MH[120]')
#  --->  <ROOT.RooRealVar object ("MH") at 0x88d3ae0>
# RooWorkspace::factory('N_B2mu[1000,0,1]')
#  --->  <ROOT.RooRealVar object ("N_B2mu") at 0x8977850>
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing ProcessNormalization::n_exp_bincat1_proc_mu
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing ProcessNormalization::n_exp_bincat1_proc_tau
# recyling (cat1,mu,) -> shapeBkg_mu_cat1
#
# recyling (cat1,mu,) -> shapeBkg_mu_cat1
#
# recyling (cat1,tau,) -> shapeSig_tau_cat1
#
# recyling (cat1,tau,) -> shapeSig_tau_cat1
#
# Creating RooAddPdf pdf_bincat1 with 2 elements
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooCategory::CMS_channel for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddPdf::pdf_bincat1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::CMS_th1x for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of ProcessNormalization::n_exp_bincat1_proc_mu for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::N_B2mu for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing FastVerticalInterpHistPdf2::shapeSig_tau_cat1_rebinPdf
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of ProcessNormalization::n_exp_bincat1_proc_tau for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::r for import of RooSimultaneousOpt::model_s
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooSimultaneousOpt::model_b
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooCategory::CMS_channel for import of RooSimultaneousOpt::model_b
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddPdf::pdf_bincat1_bonly
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf for import of RooSimultaneousOpt::model_b
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::CMS_th1x for import of RooSimultaneousOpt::model_b
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of ProcessNormalization::n_exp_bincat1_proc_mu for import of RooSimultaneousOpt::model_b
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::N_B2mu for import of RooSimultaneousOpt::model_b
#
# === Using the following for ModelConfig ===
# Observables:             RooArgSet:: = (CMS_th1x,CMS_channel)
# Parameters of Interest:  RooArgSet:: = (r)
# PDF:                     RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
#
#
# === Using the following for ModelConfig_bonly ===
# Observables:             RooArgSet:: = (CMS_th1x,CMS_channel)
# Parameters of Interest:  RooArgSet:: = (r)
# PDF:                     RooSimultaneousOpt::model_b[ indexCat=CMS_channel cat1=pdf_bincat1_bonly extraConstraints=() channelMasks=() ] = 0.0761978
#
#
# RooWorkspace(w) w contents
#
# variables
# ---------
# (CMS_channel,CMS_th1x,MH,N_B2mu,r)
#
# p.d.f.s
# -------
# RooSimultaneousOpt::model_b[ indexCat=CMS_channel cat1=pdf_bincat1_bonly extraConstraints=() channelMasks=() ] = 0.0761978
#   RooAddPdf::pdf_bincat1_bonly[ n_exp_bincat1_proc_mu * shapeBkg_mu_cat1_rebinPdf ] = 0.0761978
#     FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.0761978
#     ProcessNormalization::n_exp_bincat1_proc_mu[ thetaList=() asymmThetaList=() otherFactorList=(N_B2mu) ] = 1000
# RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
#   RooAddPdf::pdf_bincat1[ n_exp_bincat1_proc_mu * shapeBkg_mu_cat1_rebinPdf + n_exp_bincat1_proc_tau * shapeSig_tau_cat1_rebinPdf ] = 0.119047
#     FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.0761978
#     FastVerticalInterpHistPdf2::shapeSig_tau_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.161897
#     ProcessNormalization::n_exp_bincat1_proc_mu[ thetaList=() asymmThetaList=() otherFactorList=(N_B2mu) ] = 1000
#     ProcessNormalization::n_exp_bincat1_proc_tau[ thetaList=() asymmThetaList=() otherFactorList=(r,N_B2mu) ] = 1000
#
# datasets
# --------
# RooDataSet::dataObs(CMS_th1x,CMS_channel)
#
# named sets
# ----------
# ModelConfig_Observables:(CMS_th1x,CMS_channel)
# ModelConfig_POI:(r)
# ModelConfig_bonly_Observables:(CMS_th1x,CMS_channel)
# ModelConfig_bonly_POI:(r)
# POI:(r)
# observables:(CMS_th1x,CMS_channel)
#
# generic objects
# ---------------
# RooStats::ModelConfig::ModelConfig
# RooStats::ModelConfig::ModelConfig_bonly
# RooArgSet::discreteParams
#
# Wrote GraphVizTree of model_s to  roostats-My9Rqb.root.dot
# Adding /afs/cern.ch/work/o/ocerri/CMSSW_10_2_3/src to include path
# Adding /cvmfs/cms.cern.ch/slc7_amd64_gcc700/lcg/root/6.12.07-gnimlf5//include to include path
# Input workspace 'w':
#
# RooWorkspace(w) w contents
#
# variables
# ---------
# (CMS_channel,CMS_th1x,MH,N_B2mu,r)
#
# p.d.f.s
# -------
# RooSimultaneousOpt::model_b[ indexCat=CMS_channel cat1=pdf_bincat1_bonly extraConstraints=() channelMasks=() ] = 0.0761978
# RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
# RooAddPdf::pdf_bincat1[ n_exp_bincat1_proc_mu * shapeBkg_mu_cat1_rebinPdf + n_exp_bincat1_proc_tau * shapeSig_tau_cat1_rebinPdf ] = 0.119047
# RooAddPdf::pdf_bincat1_bonly[ n_exp_bincat1_proc_mu * shapeBkg_mu_cat1_rebinPdf ] = 0.0761978
# FastVerticalInterpHistPdf2::shapeBkg_mu_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.0761978
# FastVerticalInterpHistPdf2::shapeSig_tau_cat1_rebinPdf[ coefList=() x=CMS_th1x ] = 0.161897
#
# functions
# --------
# ProcessNormalization::n_exp_bincat1_proc_mu[ thetaList=() asymmThetaList=() otherFactorList=(N_B2mu) ] = 1000
# ProcessNormalization::n_exp_bincat1_proc_tau[ thetaList=() asymmThetaList=() otherFactorList=(r,N_B2mu) ] = 1000
#
# datasets
# --------
# RooDataSet::dataObs(CMS_th1x,CMS_channel)
#
# named sets
# ----------
# ModelConfig_Observables:(CMS_th1x,CMS_channel)
# ModelConfig_POI:(r)
# ModelConfig_bonly_Observables:(CMS_th1x,CMS_channel)
# ModelConfig_bonly_POI:(r)
# POI:(r)
# observables:(CMS_th1x,CMS_channel)
#
# generic objects
# ---------------
# RooStats::ModelConfig::ModelConfig
# RooStats::ModelConfig::ModelConfig_bonly
# RooArgSet::discreteParams
#
# Workspace has a ModelConfig for signal called 'ModelConfig', with contents:
#
# === Using the following for ModelConfig ===
# Observables:             RooArgSet:: = (CMS_th1x,CMS_channel)
# Parameters of Interest:  RooArgSet:: = (r)
# PDF:                     RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
#
# Input ModelConfig 'ModelConfig':
#
# === Using the following for ModelConfig ===
# Observables:             RooArgSet:: = (CMS_th1x,CMS_channel)
# Parameters of Interest:  RooArgSet:: = (r)
# PDF:                     RooSimultaneousOpt::model_s[ indexCat=CMS_channel cat1=pdf_bincat1 extraConstraints=() channelMasks=() ] = 0.119047
#
# Set Range of Parameter r To : (0.001,1)
# Set Default Value of Parameter r To : 0.1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooUniform::prior
# Using shapes: qui si parra' la tua nobilitate
# Will use binning variable CMS_th1x with 10 bins
# Will use category 'CMS_channel' to identify the 1 channels
# done.
# Importing combined pdf model_s
# Importing combined pdf model_b
# Setting variable 'MH' in workspace to the higgs mass 120
# Error when running the combination:
# 	Running with systematic variation in toys enabled, but I found floating parameters (which are not POIs) but no constrain terms have been defined in the datacard. If this is ok, re-run with -S 0

# %% [markdown]
# Combine them to get the p-value

# %%
cmd = 'combineTool.py'
cmd += ' -M CollectGoodnessOfFit'
cmd += ' --mass 120'
cmd += ' -o gof.json'
name_obs = glob('higgsCombineObs.GoodnessOfFit.*.root')[0]
name_toys = glob('higgsCombineToys.GoodnessOfFit.*.root')[0]
cmd += ' --input {} {}'.format(name_obs, name_toys)

# %%
print cmd
os.system(cmd)
os.system('plotGof.py gof.json -o gof --mass 120.0')
# Out:
# combineTool.py -M CollectGoodnessOfFit --mass 120 -o gof.json --input higgsCombineObs.GoodnessOfFit.mH120.-1642788361.root higgsCombineToys.GoodnessOfFit.mH120.1295348221.root
# 256
# Traceback (most recent call last):
#   File "/afs/cern.ch/work/o/ocerri/CMSSW_10_2_3/bin/slc7_amd64_gcc700/combineTool.py", line 83, in <module>
#     method.run_method()
#   File "/afs/cern.ch/work/o/ocerri/CMSSW_10_2_3/python/CombineHarvester/CombineTools/combine/Output.py", line 266, in run_method
#     for branch in tree.GetListOfBranches():
# AttributeError: 'TObject' object has no attribute 'GetListOfBranches'
# Traceback (most recent call last):
#   File "/afs/cern.ch/work/o/ocerri/CMSSW_10_2_3/bin/slc7_amd64_gcc700/plotGof.py", line 176, in <module>
#     with open(args.input) as jsfile:
# IOError: [Errno 2] No such file or directory: 'gof.json'
